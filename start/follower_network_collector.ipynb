# %%
#This notebook builds a follower network for a set of users
#first import the helper functions 
from helper_follower_network_crawler import *
import sqlite3
import pandas as pd
import random

# %%
#COLLECT FOLLOWING NETWORK
#Get the following for a set of screen names
#Filename where we will store the list of following (ends with .csv)
max_following = 2000  #maximum number of following to get per user(10 minutes for 1000 users)
max_users = int(1e4)  #maximum number of users you will build the following network for
FilenameTweetDatabase = "ReopenAmerica.db" 
FilenameFollowingNetwork = "followingnetwork_ReopenAmerica.csv"



print("Tweets will be loaded from database file %s"%FilenameTweetDatabase)
print("Follower network saved to file %s"%FilenameFollowingNetwork)

FilenameFollowingNetworkGpickle = FilenameFollowingNetwork.replace(".csv",".gpickle")
print("Follower network graph object saved to file %s"%FilenameFollowingNetworkGpickle)

print("We will collect maximum %s users, maximum %s following per user"%(max_users,max_following))
#ScreenNames is a list of the screen names you want to build the network of
#Define ScreenNames this way if you want to write the names by hand
#ScreenNames = ["zlisto"]
# Out:
# Tweets will be loaded from database file ReopenAmerica.db
# Follower network saved to file followingnetwork_ReopenAmerica.csv
# Follower network graph object saved to file followingnetwork_ReopenAmerica.gpickle
# We will collect maximum 10000 users, maximum 2000 following per user

# %%
#get the list of screen_names
conn = sqlite3.connect("%s"%FilenameTweetDatabase)
df_screen_name = pd.read_sql_query("SELECT screen_name FROM tweet", conn)
ScreenNamesAll = list(set([row[0] for row in df_screen_name.values.tolist()]))  #remove duplicate users
nusers =  len(set(ScreenNamesAll))  #total number of unique users in tweet database


#only keep max_users
if max_users<nusers:
    #ScreenNames = ScreenNamesAll[0:max_users]  #take first max_users from list
    ScreenNames = random.sample(ScreenNames,max_users)  #take random sample from list

else:
    ScreenNames = ScreenNamesAll

print("%s users in entire tweet database\nWe will build the following network for %s of them"%(nusers,len(ScreenNames)))
print("\nHere are some of your screen names:%s"%ScreenNames[0:10])
# Out:
# 782 users in entire tweet database
# We will build the following network for 782 of them
#
# Here are some of your screen names:['garyallen262', 'kerrrihaag', 'WalterNat2', 'thatmikewhite', 'NASJones333', 'riley_noyes', 'SlrRjr', 'ScottFordTVGuy', 'OkinCity', 'SandaBlueDeux']

# %%
#This function collects the following of each person in ScreenNames 
#and saves it to an Excel file (really a csv file)

#spot in ScreenNames to start your crawler from in case it crashes
#start_index = 0 for a fresh network
start_index = 0 

#temp is the list of names you will collect following for.  
#this list starts at the start_index (we do this in case your code crashes
#you can start up where you left off)
#Collection rate ~ 100 screen names per minute
temp = ScreenNames[start_index:]  
print("starting at %s"%temp[start_index])
get_friends(temp,FilenameFollowingNetwork,max_following)
# Out:
# starting at garyallen262
# 	User 1 of 782: garyallen262 has 1532 following, we will only get 2000
# 	User 2 of 782: kerrrihaag has 1054 following, we will only get 2000
# 	User 3 of 782: WalterNat2 has 361 following, we will only get 2000
# 	User 4 of 782: thatmikewhite has 0 following, we will only get 2000
# 	User 5 of 782: NASJones333 has 6111 following, we will only get 2000
# 	User 6 of 782: riley_noyes has 180 following, we will only get 2000
# 	User 7 of 782: SlrRjr has 847 following, we will only get 2000
# 	User 8 of 782: ScottFordTVGuy has 4453 following, we will only get 2000
# 	User 9 of 782: OkinCity has 2131 following, we will only get 2000
# 	User 10 of 782: SandaBlueDeux has 1129 following, we will only get 2000
# 	User 11 of 782: stxceasf has 159 following, we will only get 2000
# 	User 12 of 782: MarciaNess1 has 1273 following, we will only get 2000
# 	User 13 of 782: Faerie_Dragon has 2617 following, we will only get 2000
# 	User 14 of 782: AnthonyPktMedia has 1361 following, we will only get 2000
# 	User 15 of 782: SamSofiMama has 2049 following, we will only get 2000
# 	User 16 of 782: Rayz2cents has 78 following, we will only get 2000
# 	User 17 of 782: PJZPamela has 463 following, we will only get 2000
# 	User 18 of 782: InventAnxiety has 43 following, we will only get 2000
# 	User 19 of 782: irreverendjamie has 453 following, we will only get 2000
# 	User 20 of 782: calikat8 has 796 following, we will only get 2000
# 	User 21 of 782: EricMMatheny has 89413 following, we will only get 2000
# 	User 22 of 782: juliejbarker has 1492 following, we will only get 2000
# 	User 23 of 782: lala0202lala has 489 following, we will only get 2000
# 	User 24 of 782: JonSoki has 965 following, we will only get 2000
# 	User 25 of 782: theaaronjoby has 132 following, we will only get 2000
# 	User 26 of 782: boofcario has 497 following, we will only get 2000
# 	User 27 of 782: StephanieRuff3 has 2158 following, we will only get 2000
# 	User 28 of 782: AMotifs has 147 following, we will only get 2000
# 	User 29 of 782: cultureNbeauty has 5678 following, we will only get 2000
# 	User 30 of 782: QZThaLeader has 1484 following, we will only get 2000
# 	User 31 of 782: sj_martin has 575 following, we will only get 2000
# 	User 32 of 782: MLechatnoir has 125 following, we will only get 2000
# 	User 33 of 782: Dawsond88Dawson has 62 following, we will only get 2000
# 	User 34 of 782: AccActivist has 5658 following, we will only get 2000
# 	User 35 of 782: DiDi23603670 has 2026 following, we will only get 2000
# 	User 36 of 782: TabberAnn has 5001 following, we will only get 2000
# 	User 37 of 782: VroommVroommNow has 3691 following, we will only get 2000
# 	User 38 of 782: gonzalezderwin has 4918 following, we will only get 2000
# 	User 39 of 782: spatula75 has 452 following, we will only get 2000
# 	User 40 of 782: LucyNadeau has 74 following, we will only get 2000
# 	User 42 of 782: Laureolus has 153 following, we will only get 2000
# 	User 43 of 782: AbstractDepths has 63 following, we will only get 2000
# 	User 44 of 782: Ponteelcinturon has 3070 following, we will only get 2000
# 	User 45 of 782: chrisfayers has 55929 following, we will only get 2000
# 	User 46 of 782: Bunny_daPug has 5123 following, we will only get 2000
# 	User 47 of 782: kbh7981 has 384 following, we will only get 2000
# 	User 48 of 782: lmerrim has 80 following, we will only get 2000
# 	User 49 of 782: itsjamarifox has 633 following, we will only get 2000
# 	User 50 of 782: leleyi has 23 following, we will only get 2000
# 	User 51 of 782: NikiGjoni has 1294 following, we will only get 2000
# 	User 52 of 782: SKOL_N_BONES has 727 following, we will only get 2000
# 	User 53 of 782: peaksoil has 767 following, we will only get 2000
# 	User 54 of 782: SamuraiElf has 1908 following, we will only get 2000
# 	User 55 of 782: MariaMe42546452 has 1424 following, we will only get 2000
# 	User 56 of 782: You_and_me_1991 has 1505 following, we will only get 2000
# 	User 57 of 782: ShitpostingMl has 30 following, we will only get 2000
# 	User 58 of 782: Raccoonrabb21s has 721 following, we will only get 2000
# 	User 59 of 782: Psychic_Kumquat has 1855 following, we will only get 2000
# 	User 60 of 782: dethollandmarch has 133 following, we will only get 2000
# 	User 61 of 782: Alondrizzy232 has 117 following, we will only get 2000
# 	User 62 of 782: kerley_shawn has 174 following, we will only get 2000
# 	User 63 of 782: MoomaCat has 4964 following, we will only get 2000
# 	User 64 of 782: Swalter255 has 1466 following, we will only get 2000
# 	User 65 of 782: lisagee1234 has 767 following, we will only get 2000
# 	User 66 of 782: sharona911 has 673 following, we will only get 2000
# 	User 67 of 782: N4keZer0 has 2310 following, we will only get 2000
# 	User 68 of 782: MackTweets_445 has 3314 following, we will only get 2000
# 	User 69 of 782: 43Juliet has 81 following, we will only get 2000
# 	User 70 of 782: _In0therWords_ has 1 following, we will only get 2000
# 	User 71 of 782: MkGae has 70 following, we will only get 2000
# 	User 72 of 782: AdaireJarrett has 277 following, we will only get 2000
# 	User 73 of 782: NinaNighting has 48 following, we will only get 2000
# 	User 74 of 782: Sexy_LatinStuds has 195 following, we will only get 2000
# 	User 75 of 782: MysterDL has 47 following, we will only get 2000
# 	User 76 of 782: omgxlori has 1647 following, we will only get 2000
# 	User 77 of 782: emaxwell1 has 822 following, we will only get 2000
# 	User 78 of 782: cmitch2108 has 953 following, we will only get 2000
# 	User 79 of 782: bewolf72492054 has 8 following, we will only get 2000
# 	User 80 of 782: ashleyann20 has 154 following, we will only get 2000
# 	User 81 of 782: KatNaps3 has 232 following, we will only get 2000
# 	User 82 of 782: MasterTheBig3 has 223 following, we will only get 2000
# 	User 83 of 782: 9ThirtyFour has 53 following, we will only get 2000
# 	User 84 of 782: JosephB48525823 has 10 following, we will only get 2000
# 	User 85 of 782: wandhand has 352 following, we will only get 2000
# 	User 86 of 782: GivWeeseAChance has 123 following, we will only get 2000
# 	User 87 of 782: EmptyHandedLove has 269 following, we will only get 2000
# 	User 88 of 782: Jordan81007378 has 132 following, we will only get 2000
# 	User 89 of 782: 2020ResistBotU1 has 3958 following, we will only get 2000
# 	User 90 of 782: mfh1651 has 125 following, we will only get 2000
# 	User 91 of 782: scotty321 has 344 following, we will only get 2000
# 	User 92 of 782: Soulio2 has 169 following, we will only get 2000
# 	User 93 of 782: KowalczykBrian has 416 following, we will only get 2000
# 	User 94 of 782: fool4thetruth has 4473 following, we will only get 2000
# 	User 95 of 782: Ginafurlynn has 3714 following, we will only get 2000
# 	User 96 of 782: jpprime01 has 2353 following, we will only get 2000
# 	User 97 of 782: itsZbro9412 has 353 following, we will only get 2000
# 	User 98 of 782: james_murphree has 18 following, we will only get 2000
# 	User 99 of 782: _ReaalAmerican_ has 19100 following, we will only get 2000
# 	User 100 of 782: brixtowall has 16 following, we will only get 2000
# 	User 101 of 782: bizacco has 1323 following, we will only get 2000
# 	User 102 of 782: _JustJav has 598 following, we will only get 2000
# 	User 103 of 782: CamperCarol2 has 539 following, we will only get 2000
# 	User 104 of 782: migueli0n has 941 following, we will only get 2000
# 	User 105 of 782: ladyvictoria8 has 6319 following, we will only get 2000
# 	User 106 of 782: nicamadrid02 has 1280 following, we will only get 2000
# 	User 107 of 782: helenmpls has 85 following, we will only get 2000
# 	User 108 of 782: Rezzenstein has 433 following, we will only get 2000
# 	User 109 of 782: thegaf has 1890 following, we will only get 2000
# 	User 110 of 782: IWillRoam has 1924 following, we will only get 2000
# 	User 111 of 782: lockeye has 174 following, we will only get 2000
# 	User 112 of 782: djwaglmuffin has 1834 following, we will only get 2000
# 	User 113 of 782: HankeyPolly has 497 following, we will only get 2000
# 	User 114 of 782: umbreonbynight has 162 following, we will only get 2000
# 	User 115 of 782: Fan_of_Flo has 56 following, we will only get 2000
# 	User 116 of 782: SassyLa35278765 has 6285 following, we will only get 2000
# 	User 117 of 782: NoirPoetograpy has 815 following, we will only get 2000
# 	User 118 of 782: CMMV_vt has 1857 following, we will only get 2000
# 	User 119 of 782: TRE45ON has 1577 following, we will only get 2000
# 	User 120 of 782: ComradeSquidwrd has 327 following, we will only get 2000
# 	User 121 of 782: DawnKayePunch has 425 following, we will only get 2000
# 	User 122 of 782: russianasshat has 547 following, we will only get 2000
# 	User 123 of 782: Dyann057 has 12660 following, we will only get 2000
# 	User 124 of 782: ElinorJoneser has 620 following, we will only get 2000
# 	User 125 of 782: pinklionheart has 4190 following, we will only get 2000
# 	User 126 of 782: SarahRamsingh has 3714 following, we will only get 2000
# 	User 127 of 782: digitaldart has 4929 following, we will only get 2000
# 	User 128 of 782: InsanePotus has 2439 following, we will only get 2000
# 	User 129 of 782: YouWontFeelThis has 10 following, we will only get 2000
# 	User 130 of 782: MEMcovfefe4 has 8185 following, we will only get 2000
# 	User 131 of 782: MrWhooz has 141 following, we will only get 2000
# 	User 132 of 782: artisteboy has 1130 following, we will only get 2000
# 	User 133 of 782: FrontPaigeStory has 601 following, we will only get 2000
# 	User 134 of 782: DebdLun has 2739 following, we will only get 2000
# 	User 135 of 782: sdbraz has 7997 following, we will only get 2000
# 	User 136 of 782: Scarlet441 has 151 following, we will only get 2000
# 	User 137 of 782: JakeKornegay has 130 following, we will only get 2000
# 	User 138 of 782: BarbaraMain07 has 20509 following, we will only get 2000
# 	User 139 of 782: prothero_james has 4702 following, we will only get 2000
# 	User 140 of 782: EdmundMP has 489 following, we will only get 2000
# 	User 141 of 782: almescudii has 169 following, we will only get 2000
# 	User 142 of 782: RALPH4lyf has 2841 following, we will only get 2000
# 	User 143 of 782: Happygo62185195 has 3702 following, we will only get 2000
# 	User 144 of 782: afacelessnurse has 622 following, we will only get 2000
# 	User 145 of 782: BeingJelly has 174 following, we will only get 2000
# 	User 146 of 782: reversedimages1 has 3539 following, we will only get 2000
# 	User 147 of 782: Jordybrett has 2308 following, we will only get 2000
# 	User 148 of 782: museumsrus has 1056 following, we will only get 2000
# 	User 149 of 782: Gingerbread0157 has 76 following, we will only get 2000
# 	User 150 of 782: MissLynx1990 has 11113 following, we will only get 2000
# 	User 151 of 782: JanetThoma has 4999 following, we will only get 2000
# 	User 152 of 782: CiTYgOtGRiND has 420 following, we will only get 2000
# 	User 153 of 782: Andrews034 has 387 following, we will only get 2000
# 	User 154 of 782: ImThatGuy1975 has 117 following, we will only get 2000
# 	User 155 of 782: JustBeingJessie has 734 following, we will only get 2000
# 	User 156 of 782: Ktbellamy9Keith has 261 following, we will only get 2000
# 	User 157 of 782: Thazsurf has 329 following, we will only get 2000
# 	User 158 of 782: Steelersgrl36 has 1638 following, we will only get 2000
# 	User 159 of 782: AndzLandz has 1095 following, we will only get 2000
# 	User 160 of 782: jonese2019 has 189 following, we will only get 2000
# 	User 161 of 782: Jennife26596400 has 22 following, we will only get 2000
# 	User 162 of 782: markjamessy has 179 following, we will only get 2000
# 	User 163 of 782: BigOilandGas has 3943 following, we will only get 2000
# 	User 164 of 782: molinari73 has 2946 following, we will only get 2000
# 	User 165 of 782: Lisa82883894 has 671 following, we will only get 2000
# 	User 166 of 782: DagnyDelinquent has 3858 following, we will only get 2000
# 	User 167 of 782: MadCyclistNYC has 3133 following, we will only get 2000
# 	User 168 of 782: elaine6362 has 5297 following, we will only get 2000
# 	User 169 of 782: swmstn2 has 3348 following, we will only get 2000
# 	User 170 of 782: TamiSFGiantFan has 5608 following, we will only get 2000
# 	User 171 of 782: KateKelley1973 has 298 following, we will only get 2000
# 	User 172 of 782: silky_thi_hi has 198 following, we will only get 2000
# 	User 173 of 782: fairside231 has 53 following, we will only get 2000
# 	User 174 of 782: ShavvyMack has 303 following, we will only get 2000
# 	User 175 of 782: AishaChan16 has 1274 following, we will only get 2000
# 	User 176 of 782: ZikeBucan has 754 following, we will only get 2000
# 	User 177 of 782: shoofrey has 152 following, we will only get 2000
# 	User 178 of 782: JaimeFrcknRamos has 1084 following, we will only get 2000
# 	User 179 of 782: HassaninDC has 1786 following, we will only get 2000
# 	User 180 of 782: GS_VCactivist has 2374 following, we will only get 2000
# 	User 181 of 782: thirsty4Groff has 434 following, we will only get 2000
# 	User 182 of 782: cantcatchmeeeee has 422 following, we will only get 2000
# 	User 183 of 782: lagranbxtch has 331 following, we will only get 2000
# 	User 184 of 782: Jamierodr14 has 24331 following, we will only get 2000
# 	User 185 of 782: sturgishigh has 4481 following, we will only get 2000
# 	User 186 of 782: torimani_ has 1195 following, we will only get 2000
# 	User 187 of 782: BrauneisAmy has 14703 following, we will only get 2000
# 	User 188 of 782: FredsCondom has 3 following, we will only get 2000
# 	User 189 of 782: MadeInJamaica5 has 17 following, we will only get 2000
# 	User 190 of 782: Shadetree_TX has 1358 following, we will only get 2000
# 	User 191 of 782: saintbonard has 113 following, we will only get 2000
# 	User 192 of 782: MaryMarybrogdon has 3478 following, we will only get 2000
# 	User 193 of 782: CreationsOwner has 2741 following, we will only get 2000
# 	User 194 of 782: tired_fighting has 1471 following, we will only get 2000
# 	User 195 of 782: thfirekeeper has 35 following, we will only get 2000
# 	User 196 of 782: judymcd88944991 has 47 following, we will only get 2000
# 	User 197 of 782: EllieTrinowski has 2100 following, we will only get 2000
# 	User 198 of 782: jovuuv has 100 following, we will only get 2000
# 	User 199 of 782: raptormurph has 357 following, we will only get 2000
# 	User 200 of 782: NoSePuedeCreer1 has 1948 following, we will only get 2000
# 	User 201 of 782: HoneyGuwop has 1404 following, we will only get 2000
# 	User 202 of 782: truspokonomics has 10 following, we will only get 2000
# 	User 203 of 782: MassenaFlyBoy has 5781 following, we will only get 2000
# 	User 204 of 782: 21stcenturyfred has 5464 following, we will only get 2000
# 	User 205 of 782: Bonfit3 has 6 following, we will only get 2000
# 	User 206 of 782: tjennings_art has 491 following, we will only get 2000
# 	User 207 of 782: kai_ady has 100 following, we will only get 2000
# 	User 208 of 782: alieward has 1009 following, we will only get 2000
# 	User 209 of 782: Pooz1969 has 5935 following, we will only get 2000
# 	User 210 of 782: fivelsgirl has 989 following, we will only get 2000
# 	User 211 of 782: ofliesandhope has 193 following, we will only get 2000
# 	User 212 of 782: CarolYMorrisse1 has 2666 following, we will only get 2000
# 	User 213 of 782: StoryParrott has 121 following, we will only get 2000
# 	User 214 of 782: Comebackseasonn has 1060 following, we will only get 2000
# 	User 215 of 782: EricRee53251019 has 5004 following, we will only get 2000
# 	User 216 of 782: themadkatter1 has 1323 following, we will only get 2000
# 	User 217 of 782: KateDaGreat1111 has 8909 following, we will only get 2000
# 	User 218 of 782: spudchapp has 3774 following, we will only get 2000
# 	User 219 of 782: LukeEverhart1 has 614 following, we will only get 2000
# 	User 220 of 782: IversonMorgan has 355 following, we will only get 2000
# 	User 221 of 782: BLignell has 996 following, we will only get 2000
# 	User 222 of 782: EVinTX has 639 following, we will only get 2000
# 	User 223 of 782: bugsm5 has 1398 following, we will only get 2000
# 	User 224 of 782: AuntHatties has 153 following, we will only get 2000
# 	User 225 of 782: Rfranz19 has 1446 following, we will only get 2000
# 	User 226 of 782: Ilkersezerrr has 2577 following, we will only get 2000
# 	User 227 of 782: QuackQuackImDog has 47 following, we will only get 2000
# 	User 228 of 782: gil22768 has 391 following, we will only get 2000
# 	User 229 of 782: sardal283 has 136 following, we will only get 2000
# 	User 230 of 782: 4URspeculation has 2684 following, we will only get 2000
# 	User 231 of 782: Robyn8821789 has 4209 following, we will only get 2000
# 	User 232 of 782: Roneyclan has 130 following, we will only get 2000
# 	User 233 of 782: gzr3625 has 352 following, we will only get 2000
# 	User 234 of 782: sampanico has 1079 following, we will only get 2000
# 	User 235 of 782: BLKGayProudDem has 2595 following, we will only get 2000
# 	User 236 of 782: simeyowen has 1870 following, we will only get 2000
# 	User 237 of 782: NotTheSydneyA has 1202 following, we will only get 2000
# 	User 238 of 782: Designsage has 8303 following, we will only get 2000
# 	User 239 of 782: JeSuisBernie has 1039 following, we will only get 2000
# 	User 240 of 782: gaj724 has 15215 following, we will only get 2000
# 	User 241 of 782: JamesMeroney has 3952 following, we will only get 2000
# 	User 242 of 782: NBA_Scholar has 1167 following, we will only get 2000
# 	User 243 of 782: Dougiee812 has 87 following, we will only get 2000
# 	User 244 of 782: 243lbsYeahRight has 504 following, we will only get 2000
# 	User 245 of 782: simplyjazzy__ has 961 following, we will only get 2000
# 	User 246 of 782: SonicWindAttack has 394 following, we will only get 2000
# 	User 247 of 782: DMasonMoore1 has 245 following, we will only get 2000
# 	User 248 of 782: RESQME37 has 57 following, we will only get 2000
# 	User 249 of 782: LizMiserables00 has 4504 following, we will only get 2000
# 	User 250 of 782: JennHarp1 has 276 following, we will only get 2000
# 	User 251 of 782: AnooshInTheSun has 3146 following, we will only get 2000
# 	User 252 of 782: natsimpcmd has 240 following, we will only get 2000
# 	User 253 of 782: SergMylili has 158 following, we will only get 2000
# 	User 254 of 782: cyndeZu has 2990 following, we will only get 2000
# 	User 255 of 782: orangestreak has 3826 following, we will only get 2000
# 	User 256 of 782: CaroleMyers has 8467 following, we will only get 2000
# 	User 257 of 782: BarbLettieri has 2640 following, we will only get 2000
# 	User 258 of 782: SJerseyGirl has 121 following, we will only get 2000
# 	User 259 of 782: octobersoo has 486 following, we will only get 2000
# 	User 260 of 782: luv_wins_ has 1636 following, we will only get 2000
# 	User 261 of 782: MsCranky2 has 44 following, we will only get 2000
# 	User 262 of 782: DrMcGoodBody1 has 38 following, we will only get 2000
# 	User 263 of 782: buchen_patricia has 2544 following, we will only get 2000
# 	User 264 of 782: DebraBashaw1 has 80 following, we will only get 2000
# 	User 265 of 782: CapitolClownCar has 845 following, we will only get 2000
# 	User 266 of 782: tweetsthecreeps has 3799 following, we will only get 2000
# 	User 267 of 782: NeneJoh28370575 has 521 following, we will only get 2000
# 	User 268 of 782: draterus has 2070 following, we will only get 2000
# 	User 269 of 782: Jenbr2 has 60 following, we will only get 2000
# 	User 270 of 782: MikefromFLA has 306 following, we will only get 2000
# 	User 271 of 782: BrianaBridges11 has 491 following, we will only get 2000
# 	User 272 of 782: heavenshaffer27 has 37 following, we will only get 2000
# 	User 273 of 782: robbiegj11 has 10422 following, we will only get 2000
# 	User 274 of 782: Blake_B25 has 284 following, we will only get 2000
# 	User 275 of 782: JolieBelle_ has 734 following, we will only get 2000
# 	User 276 of 782: JoeCotellese has 1060 following, we will only get 2000
# 	User 277 of 782: FaZe_BOT has 0 following, we will only get 2000
# 	User 278 of 782: IcarusAlso has 205 following, we will only get 2000
# 	User 279 of 782: jennaudrey has 3185 following, we will only get 2000
# 	User 280 of 782: HoRSE_1758 has 7 following, we will only get 2000
# 	User 281 of 782: darbonnjohn has 691 following, we will only get 2000
# 	User 282 of 782: pinhead71 has 580 following, we will only get 2000
# 	User 283 of 782: KathyDi86 has 428 following, we will only get 2000
# 	User 284 of 782: hyamesrhymes has 372 following, we will only get 2000
# 	User 285 of 782: EggExodus has 5006 following, we will only get 2000
# 	User 286 of 782: AnorveRaul has 211 following, we will only get 2000
# 	User 287 of 782: BobbiSm04990900 has 701 following, we will only get 2000
# 	User 288 of 782: babylon_slim has 2486 following, we will only get 2000
# 	User 289 of 782: spaceiphany has 3162 following, we will only get 2000
# 	User 290 of 782: WQrdsmith has 300 following, we will only get 2000
# 	User 291 of 782: cajun_black has 91 following, we will only get 2000
# 	User 292 of 782: NyyRecaps has 159 following, we will only get 2000
# 	User 293 of 782: Uber__Pie has 1070 following, we will only get 2000
# 	User 294 of 782: melaniesdavis has 3754 following, we will only get 2000
# 	User 295 of 782: kayfernandez72 has 543 following, we will only get 2000
# 	User 296 of 782: Lavinlml1 has 146 following, we will only get 2000
# 	User 297 of 782: GoTyme_ has 33 following, we will only get 2000
# 	User 298 of 782: SusanSusie17 has 108 following, we will only get 2000
# 	User 299 of 782: CollectiveMindP has 609 following, we will only get 2000
# 	User 300 of 782: 2PLAN22 has 4930 following, we will only get 2000
# 	User 301 of 782: ashleynicolex10 has 294 following, we will only get 2000
# 	User 302 of 782: Grace20704909 has 119 following, we will only get 2000
# 	User 303 of 782: NEWS__BBC has 284 following, we will only get 2000
# 	User 304 of 782: Brygida_Poland has 613 following, we will only get 2000
# 	User 305 of 782: snarkysnowqueen has 759 following, we will only get 2000
# 	User 307 of 782: dubblasta has 418 following, we will only get 2000
# 	User 308 of 782: zzerotheher0 has 17 following, we will only get 2000
# 	User 309 of 782: saramiraglia has 355 following, we will only get 2000
# 	User 310 of 782: SouthOVegas has 3463 following, we will only get 2000
# 	User 311 of 782: gunsetmelo has 5849 following, we will only get 2000
# 	User 312 of 782: AprilMicheleRh2 has 2491 following, we will only get 2000
# 	User 313 of 782: meowderon has 135 following, we will only get 2000
# 	User 314 of 782: RetiredDPO21 has 52 following, we will only get 2000
# 	User 315 of 782: P1MPYADDY has 45 following, we will only get 2000
# 	User 316 of 782: LindaQVillan has 1932 following, we will only get 2000
# 	User 317 of 782: Radhaze_ has 72 following, we will only get 2000
# 	User 318 of 782: corgihorse has 903 following, we will only get 2000
# 	User 319 of 782: ging_nancy has 35 following, we will only get 2000
# 	User 320 of 782: christielynn42 has 494 following, we will only get 2000
# 	User 321 of 782: alexclementine0 has 544 following, we will only get 2000
# 	User 322 of 782: Kenzer24213 has 304 following, we will only get 2000
# 	User 323 of 782: Jenovia has 130 following, we will only get 2000
# 	User 324 of 782: cheriosmith has 1664 following, we will only get 2000
# 	User 325 of 782: AmberRose has 1340 following, we will only get 2000
# 	User 326 of 782: EvelynYvonneT has 3194 following, we will only get 2000
# 	User 327 of 782: JamesTScorpio1 has 1333 following, we will only get 2000
# 	User 328 of 782: AaronFown has 643 following, we will only get 2000
# 	User 329 of 782: RealTwitish has 16042 following, we will only get 2000
# 	User 330 of 782: TheSpiritJuice has 229 following, we will only get 2000
# 	User 331 of 782: chickenlegz51 has 719 following, we will only get 2000
# 	User 332 of 782: JimBowiePerry has 3992 following, we will only get 2000
# 	User 333 of 782: MsBianca_xo has 614 following, we will only get 2000
# 	User 334 of 782: celianauburn has 3712 following, we will only get 2000
# 	User 335 of 782: kshering has 10158 following, we will only get 2000
# 	User 336 of 782: RealDDogHours has 410 following, we will only get 2000
# 	User 337 of 782: Jonconway2874 has 349 following, we will only get 2000
# 	User 338 of 782: Sokoloff_Sid has 123 following, we will only get 2000
# 	User 339 of 782: StephCards has 204 following, we will only get 2000
# 	User 340 of 782: maddenifico has 71719 following, we will only get 2000
# 	User 341 of 782: Sarashara7 has 437 following, we will only get 2000
# 	User 342 of 782: harleyandmackie has 10429 following, we will only get 2000
# 	User 343 of 782: UniversalSoul9 has 460 following, we will only get 2000
# 	User 344 of 782: iamacanuck has 879 following, we will only get 2000
# 	User 345 of 782: kathyawatson3 has 1099 following, we will only get 2000
# 	User 346 of 782: BernieDoesIt has 6521 following, we will only get 2000
# 	User 347 of 782: NarfNot has 469 following, we will only get 2000
# 	User 348 of 782: ElkeHollings has 314 following, we will only get 2000
# 	User 349 of 782: schoonercove1 has 3094 following, we will only get 2000
# 	User 350 of 782: cherokeesher2 has 28443 following, we will only get 2000
# 	User 351 of 782: Diamondniamack has 269 following, we will only get 2000
# 	User 352 of 782: saramikaila has 5030 following, we will only get 2000
# 	User 353 of 782: CenterRightGuy has 14 following, we will only get 2000
# 	User 354 of 782: bkgut3 has 9663 following, we will only get 2000
# 	User 355 of 782: TheWriteDiva has 321 following, we will only get 2000
# 	User 356 of 782: bodacious_bear has 1374 following, we will only get 2000
# 	User 357 of 782: J0Marshll has 1057 following, we will only get 2000
# 	User 358 of 782: oliver_lexi has 647 following, we will only get 2000
# 	User 359 of 782: epena_dev has 66 following, we will only get 2000
# 	User 360 of 782: nedobis has 1591 following, we will only get 2000
# 	User 361 of 782: _simonchandler_ has 797 following, we will only get 2000
# 	User 362 of 782: VbagExtremist has 858 following, we will only get 2000
# 	User 363 of 782: AngryFedupVtr has 24985 following, we will only get 2000
# 	User 364 of 782: skezix has 340 following, we will only get 2000
# 	User 365 of 782: AmirTalai has 587 following, we will only get 2000
# 	User 366 of 782: xxdr_zombiexx has 6687 following, we will only get 2000
# 	User 367 of 782: MummaSadie has 2385 following, we will only get 2000
# 	User 368 of 782: kat_reinhardt has 687 following, we will only get 2000
# 	User 369 of 782: awoman_scorned has 920 following, we will only get 2000
# 	User 370 of 782: EricExtempore has 4338 following, we will only get 2000
# 	User 371 of 782: jonathanjewel has 14814 following, we will only get 2000
# 	User 372 of 782: Endswell357 has 1153 following, we will only get 2000
# 	User 373 of 782: moehigs has 8568 following, we will only get 2000
# 	User 374 of 782: f1reflyy has 439 following, we will only get 2000
# 	User 375 of 782: ArthurHolmberg has 102 following, we will only get 2000
# 	User 376 of 782: Postalkim1 has 907 following, we will only get 2000
# 	User 377 of 782: ablcrvnts44 has 906 following, we will only get 2000
# 	User 378 of 782: CHERYL65266557 has 152 following, we will only get 2000
# 	User 379 of 782: jabailpan has 767 following, we will only get 2000
# 	User 380 of 782: slimsexy840 has 990 following, we will only get 2000
# 	User 381 of 782: macfitte has 1636 following, we will only get 2000
# 	User 382 of 782: BarbaraWieczor7 has 12065 following, we will only get 2000
# 	User 383 of 782: Craizooo has 588 following, we will only get 2000
# 	User 384 of 782: leanleft1 has 2378 following, we will only get 2000
# 	User 385 of 782: nickialanoche has 24022 following, we will only get 2000
# 	User 386 of 782: JRehling has 46946 following, we will only get 2000
# 	User 387 of 782: forsomemasses has 993 following, we will only get 2000
# 	User 388 of 782: jromeroll has 103 following, we will only get 2000
# 	User 389 of 782: Chris_Romero98 has 280 following, we will only get 2000
# 	User 390 of 782: NayaleMeck has 1035 following, we will only get 2000
# 	User 391 of 782: LisaLisamhe has 2255 following, we will only get 2000
# 	User 392 of 782: ChristineCalca2 has 601 following, we will only get 2000
# 	User 393 of 782: Onebabybuffalo has 935 following, we will only get 2000
# 	User 394 of 782: big_bawdy has 897 following, we will only get 2000
# 	User 395 of 782: sherpamomto4 has 3025 following, we will only get 2000
# 	User 396 of 782: ___feat has 860 following, we will only get 2000
# 	User 397 of 782: CrailD has 847 following, we will only get 2000
# 	User 398 of 782: LithuanianRob has 4783 following, we will only get 2000
# 	User 399 of 782: MyScarletFelony has 4996 following, we will only get 2000
# 	User 400 of 782: JosephRMeyer has 3796 following, we will only get 2000
# 	User 401 of 782: Lawswill_ has 508 following, we will only get 2000
# 	User 402 of 782: ThunderBay43 has 4665 following, we will only get 2000
# 	User 403 of 782: krummel503 has 5445 following, we will only get 2000
# 	User 404 of 782: annacostellox has 401 following, we will only get 2000
# 	User 405 of 782: phlashez has 1040 following, we will only get 2000
# 	User 406 of 782: HelloKittyCat85 has 796 following, we will only get 2000
# 	User 407 of 782: rgMafi has 135 following, we will only get 2000
# 	User 408 of 782: sjerseymel has 130 following, we will only get 2000
# 	User 409 of 782: Inhago has 2089 following, we will only get 2000
# 	User 410 of 782: sharon_mytweets has 1984 following, we will only get 2000
# 	User 411 of 782: Perusabenji has 33 following, we will only get 2000
# 	User 412 of 782: BryHitchcock has 1610 following, we will only get 2000
# 	User 413 of 782: UncleOdit has 2255 following, we will only get 2000
# 	User 414 of 782: SelfRuling1 has 2295 following, we will only get 2000
# 	User 415 of 782: PartTimeWin has 99 following, we will only get 2000
# 	User 416 of 782: 66Vdg has 3676 following, we will only get 2000
# 	User 417 of 782: CinnamonDeluxe has 71 following, we will only get 2000
# 	User 418 of 782: ryan_huerto has 568 following, we will only get 2000
# 	User 419 of 782: Kissmykantzer has 243 following, we will only get 2000
# 	User 420 of 782: Realistic203 has 152 following, we will only get 2000
# 	User 421 of 782: meg_anneee has 87 following, we will only get 2000
# 	User 422 of 782: FarseekerF has 548 following, we will only get 2000
# 	User 423 of 782: jaskierthebard3 has 544 following, we will only get 2000
# 	User 424 of 782: CoreyDismyname has 97 following, we will only get 2000
# 	User 425 of 782: AuthorNickBella has 220 following, we will only get 2000
# 	User 426 of 782: JhbraunBraun has 75 following, we will only get 2000
# 	User 427 of 782: MostBiglyMaga has 3617 following, we will only get 2000
# 	User 428 of 782: velvethammer has 12480 following, we will only get 2000
# 	User 429 of 782: NoSympathy4 has 2270 following, we will only get 2000
# 	User 430 of 782: deerboned has 1 following, we will only get 2000
# 	User 431 of 782: meintherye_ has 795 following, we will only get 2000
# 	User 432 of 782: dreesewerrell has 76 following, we will only get 2000
# 	User 433 of 782: CAWOLFE4 has 0 following, we will only get 2000
# 	User 434 of 782: alexhamilton74 has 5625 following, we will only get 2000
# 	User 435 of 782: BarbaraCowdery has 4025 following, we will only get 2000
# 	User 436 of 782: MICHELELYNLAWR1 has 59 following, we will only get 2000
# 	User 437 of 782: PattiKimble has 16002 following, we will only get 2000
# 	User 438 of 782: Pokethulu has 800 following, we will only get 2000
# 	User 439 of 782: FilsonAndrew has 1664 following, we will only get 2000
# 	User 440 of 782: stawpfeenin has 1151 following, we will only get 2000
# 	User 441 of 782: kengkranrua has 144 following, we will only get 2000
# 	User 442 of 782: PRJAD has 2055 following, we will only get 2000
# 	User 443 of 782: ToashaAuthor has 342 following, we will only get 2000
# 	User 444 of 782: nicktoddd72 has 253 following, we will only get 2000
# 	User 445 of 782: Leftech has 422 following, we will only get 2000
# 	User 446 of 782: DavidBWriter has 1983 following, we will only get 2000
# 	User 447 of 782: sadiesez1 has 813 following, we will only get 2000
# 	User 448 of 782: SNogg3 has 2575 following, we will only get 2000
# 	User 449 of 782: HysteriaUs has 1 following, we will only get 2000
# 	User 450 of 782: actmanactnow has 428 following, we will only get 2000
# 	User 451 of 782: stompk has 1412 following, we will only get 2000
# 	User 452 of 782: vanettarather has 1214 following, we will only get 2000
# 	User 453 of 782: rsinroll has 656 following, we will only get 2000
# 	User 454 of 782: Bettercallyogi has 914 following, we will only get 2000
# 	User 455 of 782: LilithX has 3222 following, we will only get 2000
# 	User 456 of 782: WilderNomads has 926 following, we will only get 2000
# 	User 457 of 782: AlexHidell has 1029 following, we will only get 2000
# 	User 458 of 782: OctoberDawn4 has 2321 following, we will only get 2000
# 	User 459 of 782: RichCsuk has 585 following, we will only get 2000
# 	User 460 of 782: lilmaxivert has 877 following, we will only get 2000
# 	User 461 of 782: PATRICIAmethyst has 66 following, we will only get 2000
# 	User 462 of 782: scard813 has 412 following, we will only get 2000
# 	User 463 of 782: snooziedooz has 97 following, we will only get 2000
# 	User 464 of 782: LLCoool_H has 369 following, we will only get 2000
# 	User 465 of 782: cometbasement has 616 following, we will only get 2000
# 	User 466 of 782: RightAsRain7 has 7649 following, we will only get 2000
# 	User 467 of 782: BJacksonLTH has 1257 following, we will only get 2000
# 	User 468 of 782: littlemissrajvi has 70 following, we will only get 2000
# 	User 469 of 782: Get_healthy14 has 2563 following, we will only get 2000
# 	User 470 of 782: talktodenene has 1408 following, we will only get 2000
# 	User 471 of 782: Thompso55477641 has 3358 following, we will only get 2000
# 	User 472 of 782: loveandlightxox has 634 following, we will only get 2000
# 	User 473 of 782: tshayne has 76 following, we will only get 2000
# 	User 474 of 782: ChampagneStyle has 217 following, we will only get 2000
# 	User 475 of 782: LumbeeProud has 612 following, we will only get 2000
# 	User 476 of 782: its_jm_style has 53 following, we will only get 2000
# 	User 477 of 782: 4fourme has 1047 following, we will only get 2000
# 	User 478 of 782: suleymangng has 178 following, we will only get 2000
# 	User 479 of 782: CursingParrot has 5203 following, we will only get 2000
# 	User 480 of 782: Woodslight1 has 742 following, we will only get 2000
# 	User 481 of 782: gatzby_ has 575 following, we will only get 2000
# 	User 482 of 782: BraydenSegat has 215 following, we will only get 2000
# 	User 483 of 782: letahamilton383 has 4763 following, we will only get 2000
# 	User 484 of 782: Mapsydyne has 356 following, we will only get 2000
# 	User 485 of 782: BerkeleyGirl63 has 5002 following, we will only get 2000
# 	User 486 of 782: JeanTheMachine has 204 following, we will only get 2000
# 	User 487 of 782: dianademinct has 298 following, we will only get 2000
# 	User 488 of 782: ChicoBonds has 2639 following, we will only get 2000
# 	User 489 of 782: Pissyfits has 9357 following, we will only get 2000
# 	User 490 of 782: hoesworlds has 73 following, we will only get 2000
# 	User 491 of 782: ecoArtistLynch has 4163 following, we will only get 2000
# 	User 492 of 782: MarianRosin has 2016 following, we will only get 2000
# 	User 493 of 782: Fastfoodworkker has 1 following, we will only get 2000
# 	User 494 of 782: virgobrujaa has 192 following, we will only get 2000
# 	User 495 of 782: Tralfamad0re has 338 following, we will only get 2000
# 	User 496 of 782: khdietrich has 702 following, we will only get 2000
# 	User 497 of 782: D00MDayz has 51 following, we will only get 2000
# 	User 498 of 782: ssstepho has 63 following, we will only get 2000
# 	User 499 of 782: Dataanti has 58 following, we will only get 2000
# 	User 500 of 782: tinothem has 151 following, we will only get 2000
# 	User 501 of 782: sailorscarlet_ has 73 following, we will only get 2000
# 	User 502 of 782: Birchbark_Canoe has 5000 following, we will only get 2000
# 	User 503 of 782: AnnaBelBLONDE has 488 following, we will only get 2000
# 	User 504 of 782: gigibjams has 2698 following, we will only get 2000
# 	User 505 of 782: AlberoBella_NY has 2586 following, we will only get 2000
# 	User 506 of 782: 4ChionLifestyle has 12987 following, we will only get 2000
# 	User 507 of 782: MaronaPossessed has 72 following, we will only get 2000
# 	User 508 of 782: GlitchTech has 192 following, we will only get 2000
# 	User 509 of 782: Bashowicks has 853 following, we will only get 2000
# 	User 510 of 782: RetiredFFPM7 has 1878 following, we will only get 2000
# 	User 511 of 782: MickyBlueEyes17 has 5 following, we will only get 2000
# 	User 512 of 782: LeonLeFay has 2213 following, we will only get 2000
# 	User 513 of 782: normard5 has 35 following, we will only get 2000
# 	User 514 of 782: laurietangney1 has 178 following, we will only get 2000
# 	User 515 of 782: lhowe1021 has 521 following, we will only get 2000
# 	User 516 of 782: LeRealJoseRivas has 225 following, we will only get 2000
# 	User 517 of 782: ChristineDelea has 902 following, we will only get 2000
# 	User 518 of 782: Christyinpvb has 93 following, we will only get 2000
# 	User 519 of 782: lorilovesunsets has 40 following, we will only get 2000
# 	User 520 of 782: RabidDogJason has 3725 following, we will only get 2000
# 	User 521 of 782: kneroh has 152 following, we will only get 2000
# 	User 522 of 782: mandygw has 163 following, we will only get 2000
# 	User 523 of 782: mcobweb has 2551 following, we will only get 2000
# 	User 524 of 782: dreamgirl_130 has 2455 following, we will only get 2000
# 	User 525 of 782: LinneaEngstrom3 has 1557 following, we will only get 2000
# 	User 526 of 782: sherry53307719 has 7 following, we will only get 2000
# 	User 527 of 782: BRG_SanDiego has 960 following, we will only get 2000
# 	User 528 of 782: Beasley811 has 361 following, we will only get 2000
# 	User 529 of 782: DLMayo has 576 following, we will only get 2000
# 	User 530 of 782: AJGo85 has 329 following, we will only get 2000
# 	User 531 of 782: mcamm123 has 820 following, we will only get 2000
# 	User 532 of 782: _____Tweety____ has 357 following, we will only get 2000
# 	User 533 of 782: RAJESHRAJESH23 has 2564 following, we will only get 2000
# 	User 534 of 782: jennielf has 870 following, we will only get 2000
# 	User 535 of 782: storyheadjillmc has 4902 following, we will only get 2000
# 	User 536 of 782: BoxlordHunter has 75 following, we will only get 2000
# 	User 537 of 782: Sterling2143 has 770 following, we will only get 2000
# 	User 538 of 782: vpleasantries has 4995 following, we will only get 2000
# 	User 539 of 782: fighterfloyd has 144 following, we will only get 2000
# 	User 540 of 782: WillPRock has 45 following, we will only get 2000
# 	User 541 of 782: gerva78005821 has 3141 following, we will only get 2000
# 	User 542 of 782: ga_undrdawg has 4408 following, we will only get 2000
# 	User 543 of 782: donnanado has 442 following, we will only get 2000
# 	User 544 of 782: march4progress has 8046 following, we will only get 2000
# 	User 545 of 782: andycane11 has 342 following, we will only get 2000
# 	User 546 of 782: BarbaraDahl2 has 463 following, we will only get 2000
# 	User 547 of 782: JaquxyzXaiXai has 195 following, we will only get 2000
# 	User 548 of 782: Weston903 has 58 following, we will only get 2000
# 	User 549 of 782: Gamestop_CEO has 47 following, we will only get 2000
# 	User 550 of 782: DenvaPolicyGeek has 680 following, we will only get 2000
# 	User 551 of 782: sparkygirl63 has 5004 following, we will only get 2000
# 	User 552 of 782: BradyCreates_ has 614 following, we will only get 2000
# 	User 553 of 782: americancheese3 has 714 following, we will only get 2000
# 	User 554 of 782: bonitasworld has 2438 following, we will only get 2000
# 	User 555 of 782: The_Hobi_Sun has 1030 following, we will only get 2000
# 	User 556 of 782: AwesomeHyperon has 2436 following, we will only get 2000
# 	User 557 of 782: patricknflorida has 1163 following, we will only get 2000
# 	User 558 of 782: Knightkore has 5001 following, we will only get 2000
# 	User 559 of 782: bgpelaire has 728 following, we will only get 2000
# 	User 560 of 782: heidschuh has 91 following, we will only get 2000
# 	User 561 of 782: clgomn has 2208 following, we will only get 2000
# 	User 562 of 782: RP2012MLT has 3986 following, we will only get 2000
# 	User 563 of 782: earth12human has 733 following, we will only get 2000
# 	User 564 of 782: johnny_geek has 163 following, we will only get 2000
# 	User 565 of 782: threecommaz has 5 following, we will only get 2000
# 	User 566 of 782: LeeJC6_ has 17 following, we will only get 2000
# 	User 567 of 782: JesusNotTrump1 has 2854 following, we will only get 2000
# 	User 568 of 782: BrandonJLandry has 14627 following, we will only get 2000
# 	User 569 of 782: theguynamedtony has 116 following, we will only get 2000
# 	User 570 of 782: meisme318 has 1071 following, we will only get 2000
# 	User 571 of 782: Alyss426 has 368 following, we will only get 2000
# 	User 572 of 782: emspairow has 2502 following, we will only get 2000
# 	User 573 of 782: 64Dmorales has 1477 following, we will only get 2000
# 	User 574 of 782: 1waywardasshole has 361 following, we will only get 2000
# 	User 575 of 782: carlalykins has 4558 following, we will only get 2000
# 	User 576 of 782: jaredlipof has 1243 following, we will only get 2000
# 	User 577 of 782: 3xranger has 1196 following, we will only get 2000
# 	User 578 of 782: ZenCarson has 1957 following, we will only get 2000
# 	User 579 of 782: NWStauffer has 264 following, we will only get 2000
# 	User 580 of 782: Gustyweather has 914 following, we will only get 2000
# 	User 581 of 782: Somedumdum has 230 following, we will only get 2000
# 	User 582 of 782: kiaraeshi has 925 following, we will only get 2000
# 	User 583 of 782: VivianYChoe has 216 following, we will only get 2000
# 	User 584 of 782: TJfortunate has 86 following, we will only get 2000
# 	User 585 of 782: Blessed_Awesome has 3 following, we will only get 2000
# 	User 586 of 782: ruecortina has 631 following, we will only get 2000
# 	User 587 of 782: BadVirginian has 128 following, we will only get 2000
# 	User 588 of 782: jennclaros has 644 following, we will only get 2000
# 	User 589 of 782: CountryOverPar5 has 5525 following, we will only get 2000
# 	User 590 of 782: joanna_here has 159 following, we will only get 2000
# 	User 591 of 782: iiStephyii has 392 following, we will only get 2000
# 	User 592 of 782: HMcfuddlestein has 1018 following, we will only get 2000
# 	User 593 of 782: TheKayway99 has 330 following, we will only get 2000
# 	User 594 of 782: ETCisNotANumber has 64 following, we will only get 2000
# 	User 595 of 782: DHall20665248 has 4999 following, we will only get 2000
# 	User 596 of 782: PatriciaTaber has 110 following, we will only get 2000
# 	User 597 of 782: RealSteffieB has 524 following, we will only get 2000
# 	User 598 of 782: CallingAllPuts has 8 following, we will only get 2000
# 	User 599 of 782: SpeedHan has 436 following, we will only get 2000
# 	User 600 of 782: SportsBusiness4 has 713 following, we will only get 2000
# 	User 601 of 782: ellysegrace has 116 following, we will only get 2000
# 	User 602 of 782: Circle11AK has 272 following, we will only get 2000
# 	User 603 of 782: Quarternote2539 has 424 following, we will only get 2000
# 	User 604 of 782: dyro874 has 51741 following, we will only get 2000
# 	User 605 of 782: lolamen74 has 169 following, we will only get 2000
# 	User 606 of 782: AbbieYoukilis has 1134 following, we will only get 2000
# 	User 607 of 782: YoMama523 has 29 following, we will only get 2000
# 	User 608 of 782: chrlschrischris has 386 following, we will only get 2000
# 	User 609 of 782: angry_gram has 10393 following, we will only get 2000
# 	User 610 of 782: 4theluvofirepro has 48 following, we will only get 2000
# 	User 611 of 782: loomis53 has 1984 following, we will only get 2000
# 	User 612 of 782: HFHandbasket has 1301 following, we will only get 2000
# 	User 613 of 782: Fawkesbreaks has 14 following, we will only get 2000
# 	User 614 of 782: AngelRValdes has 232 following, we will only get 2000
# 	User 615 of 782: PMbeers has 24124 following, we will only get 2000
# 	User 616 of 782: thewaronstring has 1067 following, we will only get 2000
# 	User 617 of 782: mlbmom15 has 1154 following, we will only get 2000
# 	User 618 of 782: redwingsgoal has 260 following, we will only get 2000
# 	User 619 of 782: ShannonDub21 has 167 following, we will only get 2000
# 	User 620 of 782: CAPJR100 has 67 following, we will only get 2000
# 	User 621 of 782: akoji007 has 365 following, we will only get 2000
# 	User 622 of 782: AvariceKing has 274 following, we will only get 2000
# 	User 623 of 782: pkapauline1 has 1071 following, we will only get 2000
# 	User 624 of 782: gibsonmusings has 71 following, we will only get 2000
# 	User 625 of 782: HystericalChic1 has 159 following, we will only get 2000
# 	User 626 of 782: BrightMelody09 has 452 following, we will only get 2000
# 	User 627 of 782: Paul52228396 has 179 following, we will only get 2000
# 	User 628 of 782: DanCas2 has 10273 following, we will only get 2000
# 	User 629 of 782: yodaprncss has 2619 following, we will only get 2000
# 	User 630 of 782: libbywigg has 915 following, we will only get 2000
# 	User 631 of 782: bujacj has 1045 following, we will only get 2000
# 	User 632 of 782: CaramelKangaroo has 25 following, we will only get 2000
# 	User 633 of 782: IckkiKing has 1705 following, we will only get 2000
# 	User 634 of 782: OnlinePatriots has 5454 following, we will only get 2000
# 	User 635 of 782: GeneralFunk has 6486 following, we will only get 2000
# 	User 636 of 782: CleverleyDoug has 3028 following, we will only get 2000
# 	User 637 of 782: beergnome1st has 1443 following, we will only get 2000
# 	User 638 of 782: dylanslavin1 has 58 following, we will only get 2000
# 	User 639 of 782: zvchare has 43 following, we will only get 2000
# 	User 640 of 782: onahunttoday has 5137 following, we will only get 2000
# 	User 641 of 782: 6dayweek has 0 following, we will only get 2000
# 	User 642 of 782: dylanwviduya has 574 following, we will only get 2000
# 	User 643 of 782: hoviecat has 546 following, we will only get 2000
# 	User 644 of 782: NickDaisyComedy has 647 following, we will only get 2000
# 	User 645 of 782: MarkDavidWoodw1 has 9 following, we will only get 2000
# 	User 646 of 782: mariejo74206645 has 927 following, we will only get 2000
# 	User 647 of 782: rwitherspoon54 has 93 following, we will only get 2000
# 	User 648 of 782: bethweese has 118 following, we will only get 2000
# 	User 649 of 782: aaden5823 has 2795 following, we will only get 2000
# 	User 650 of 782: Freedom7Adler has 136 following, we will only get 2000
# 	User 651 of 782: debrajeanmarie has 1700 following, we will only get 2000
# 	User 652 of 782: micmac99 has 1526 following, we will only get 2000
# 	User 653 of 782: PaulaStormqueen has 594 following, we will only get 2000
# 	User 654 of 782: deborah_sheng has 64 following, we will only get 2000
# 	User 655 of 782: bboybrivnnnn has 270 following, we will only get 2000
# 	User 656 of 782: Toni_Scurlock has 7077 following, we will only get 2000
# 	User 657 of 782: jamievbred has 366 following, we will only get 2000
# 	User 658 of 782: Myozotiis has 690 following, we will only get 2000
# 	User 659 of 782: BalajiTejesvini has 49 following, we will only get 2000
# 	User 660 of 782: 1celticwomyn has 3963 following, we will only get 2000
# 	User 661 of 782: MARKPETRO1968 has 1085 following, we will only get 2000
# 	User 662 of 782: lish0531 has 6734 following, we will only get 2000
# 	User 663 of 782: Anita22332Anita has 672 following, we will only get 2000
# 	User 664 of 782: poppashot59 has 11 following, we will only get 2000
# 	User 665 of 782: kevincredible88 has 763 following, we will only get 2000
# 	User 666 of 782: janvinjoey has 6605 following, we will only get 2000
# 	User 667 of 782: sunwyn has 2505 following, we will only get 2000
# 	User 668 of 782: 01splcheck has 5191 following, we will only get 2000
# 	User 669 of 782: candisee_ has 244 following, we will only get 2000
# 	User 670 of 782: holzmadre has 977 following, we will only get 2000
# 	User 671 of 782: HannibalBarca65 has 5615 following, we will only get 2000
# 	User 672 of 782: Trmpsugly has 29225 following, we will only get 2000
# 	User 673 of 782: LostAddicted2 has 13627 following, we will only get 2000
# 	User 674 of 782: davemar79100800 has 12 following, we will only get 2000
# 	User 675 of 782: QveenJoan has 5001 following, we will only get 2000
# 	User 676 of 782: LirMihn has 1591 following, we will only get 2000
# 	User 677 of 782: JBCoke99 has 879 following, we will only get 2000
# 	User 678 of 782: lemondrops42 has 152 following, we will only get 2000
# 	User 679 of 782: SaintsGhost has 3998 following, we will only get 2000
# 	User 680 of 782: SoulaceSeeker has 146 following, we will only get 2000
# 	User 681 of 782: lindacullen has 300 following, we will only get 2000
# 	User 682 of 782: TiGGyZTweetZ has 13563 following, we will only get 2000
# 	User 683 of 782: i_am_button has 1630 following, we will only get 2000
# 	User 684 of 782: HellCat_fuego has 4571 following, we will only get 2000
# 	User 685 of 782: ZGamingZGaming has 335 following, we will only get 2000
# 	User 686 of 782: LindysTavern has 40 following, we will only get 2000
# 	User 687 of 782: MichD9NP has 1336 following, we will only get 2000
# 	User 688 of 782: SnarfxFrans has 757 following, we will only get 2000
# 	User 689 of 782: witchchilde has 2610 following, we will only get 2000
# 	User 690 of 782: lmcell2 has 2179 following, we will only get 2000
# 	User 691 of 782: beautifulexodus has 439 following, we will only get 2000
# 	User 692 of 782: mimimouse2018 has 3769 following, we will only get 2000
# 	User 693 of 782: fiestypkn has 124 following, we will only get 2000
# 	User 694 of 782: SteadyasweDodo has 7623 following, we will only get 2000
# 	User 695 of 782: profesora2005 has 1977 following, we will only get 2000
# 	User 696 of 782: sugaxmygg has 6 following, we will only get 2000
# 	User 697 of 782: VileEpiphany has 6422 following, we will only get 2000
# 	User 698 of 782: carsonjones39 has 251 following, we will only get 2000
# 	User 699 of 782: LariceLu has 1835 following, we will only get 2000
# 	User 700 of 782: virtunova has 306 following, we will only get 2000
# 	User 701 of 782: _shruthss has 368 following, we will only get 2000
# 	User 702 of 782: 0friendspodcast has 28 following, we will only get 2000
# 	User 703 of 782: ChrisBarrientes has 311 following, we will only get 2000
# 	User 704 of 782: ODDOROCK has 3235 following, we will only get 2000
# 	User 705 of 782: WendyPond123 has 273 following, we will only get 2000
# 	User 706 of 782: the_first_party has 7442 following, we will only get 2000
# 	User 707 of 782: PurpleCowMadCow has 4814 following, we will only get 2000
# 	User 708 of 782: connie_billiter has 342 following, we will only get 2000
# 	User 709 of 782: VTBox has 994 following, we will only get 2000
# 	User 710 of 782: rd01886777 has 1121 following, we will only get 2000
# 	User 711 of 782: LeslieDicken has 1521 following, we will only get 2000
# 	User 712 of 782: RicardoRiveraNJ has 410 following, we will only get 2000
# 	User 713 of 782: troubled_lady19 has 494 following, we will only get 2000
# 	User 714 of 782: Crisenusa has 1546 following, we will only get 2000
# 	User 715 of 782: morgseatingass has 0 following, we will only get 2000
# 	User 716 of 782: CassDurham1 has 50 following, we will only get 2000
# 	User 717 of 782: Jizbeano1 has 771 following, we will only get 2000
# 	User 718 of 782: Akashiya__Moka has 2315 following, we will only get 2000
# 	User 719 of 782: VSalvatori has 598 following, we will only get 2000
# 	User 720 of 782: TyrantTinyHands has 964 following, we will only get 2000
# 	User 721 of 782: DemJustice has 576 following, we will only get 2000
# 	User 722 of 782: cathonpaper has 4998 following, we will only get 2000
# 	User 723 of 782: TeamStradley has 2619 following, we will only get 2000
# 	User 724 of 782: joepatricelli has 767 following, we will only get 2000
# 	User 725 of 782: BetzMyboyblue11 has 2006 following, we will only get 2000
# 	User 726 of 782: jcvandez has 1038 following, we will only get 2000
# 	User 727 of 782: roblongwriter has 440 following, we will only get 2000
# 	User 728 of 782: GhlizzyB has 409 following, we will only get 2000
# 	User 729 of 782: Maswartz226 has 67 following, we will only get 2000
# 	User 730 of 782: preasia_wilfred has 187 following, we will only get 2000
# 	User 731 of 782: dirieone7073 has 3073 following, we will only get 2000
# 	User 732 of 782: DocJaniceL has 2947 following, we will only get 2000
# 	User 733 of 782: NativeTexan74 has 558 following, we will only get 2000
# 	User 734 of 782: AmazonianGal127 has 1215 following, we will only get 2000
# 	User 735 of 782: ChrisWallace20 has 1247 following, we will only get 2000
# 	User 736 of 782: CitadelHyperion has 105 following, we will only get 2000
# 	User 737 of 782: royaltyrell516 has 1460 following, we will only get 2000
# 	User 738 of 782: jsc1835 has 10159 following, we will only get 2000
# 	User 739 of 782: KallieBenedict has 451 following, we will only get 2000
# 	User 740 of 782: infinityhs15 has 337 following, we will only get 2000
# 	User 741 of 782: JustAddWine_ has 1661 following, we will only get 2000
# 	User 742 of 782: liltilgerlil has 11749 following, we will only get 2000
# 	User 743 of 782: saccadicmaniac has 155 following, we will only get 2000
# 	User 744 of 782: CatskillJulie has 1358 following, we will only get 2000
# 	User 745 of 782: Politifire has 7258 following, we will only get 2000
# 	User 746 of 782: FidelCostco has 862 following, we will only get 2000
# 	User 747 of 782: amyoung63 has 1987 following, we will only get 2000
# 	User 748 of 782: MercMarten has 66 following, we will only get 2000
# 	User 749 of 782: Shanti_belle has 267 following, we will only get 2000
# 	User 750 of 782: Iunecore has 399 following, we will only get 2000
# 	User 751 of 782: AxelofVenus has 1399 following, we will only get 2000
# 	User 752 of 782: macie_nicholas has 73 following, we will only get 2000
# 	User 753 of 782: meg__hn has 46 following, we will only get 2000
# 	User 754 of 782: solskennn has 277 following, we will only get 2000
# 	User 755 of 782: KiMira76 has 2014 following, we will only get 2000
# 	User 756 of 782: Texanna33 has 2095 following, we will only get 2000
# 	User 757 of 782: shanaban52 has 1118 following, we will only get 2000
# 	User 758 of 782: AliBakirdan has 1809 following, we will only get 2000
# 	User 759 of 782: PoliticalAnt has 9066 following, we will only get 2000
# 	User 760 of 782: qrosario_ has 203 following, we will only get 2000
# 	User 761 of 782: ayesa1996 has 10 following, we will only get 2000
# 	User 762 of 782: mjhubbard1 has 5440 following, we will only get 2000
# 	User 763 of 782: robinbritton11 has 9927 following, we will only get 2000
# 	User 764 of 782: ThreeCatsinaTr1 has 232 following, we will only get 2000
# 	User 765 of 782: floradoragirl has 709 following, we will only get 2000
# 	User 766 of 782: MoonAngelWings has 16931 following, we will only get 2000
# 	User 767 of 782: Patontheroad has 3159 following, we will only get 2000
# 	User 768 of 782: KLehnus has 1389 following, we will only get 2000
# 	User 769 of 782: dmfist has 4683 following, we will only get 2000
# 	User 770 of 782: mary_guild has 149 following, we will only get 2000
# 	User 771 of 782: NatSoChill has 173 following, we will only get 2000
# 	User 772 of 782: lydiabell13 has 1363 following, we will only get 2000
# 	User 773 of 782: 4closureNation2 has 3581 following, we will only get 2000
# 	User 774 of 782: OGNoFuxGiven has 4489 following, we will only get 2000
# 	User 775 of 782: MattJKoe has 693 following, we will only get 2000
# 	User 776 of 782: the_crotty has 1286 following, we will only get 2000
# 	User 777 of 782: MajJackDowning has 3845 following, we will only get 2000
# 	User 778 of 782: LindaBiersdo has 1491 following, we will only get 2000
# 	User 779 of 782: tobi_fleischman has 26 following, we will only get 2000
# 	User 780 of 782: taninthesummer has 6061 following, we will only get 2000
# 	User 781 of 782: jaketriller has 485 following, we will only get 2000
# 	User 782 of 782: chillibeanboy has 12667 following, we will only get 2000
# Finished crawling following network.  Took  483.06429958343506

# %%
#This function writes the following network to a networkx object so we can analyze it
G = write_friends_graph_tweets_networkx(ScreenNames,FilenameFollowingNetwork,FilenameFollowingNetworkGpickle)
# Out:
# Following network has 782 nodes and 27 edges
# Wrote following network to networkx object in file followingnetwork_ReopenAmerica.gpickle
